# %%
import pandas as pd
datos = pd.read_csv("spam.csv", encoding='latin-1')
datos
# Out:
#      Column1                                            Column2  Unnamed: 2  \
# 0         v1                                                 v2         NaN
# 1        ham  Go until jurong point, crazy.. Available only ...         NaN
# 2        ham                      Ok lar... Joking wif u oni...         NaN
# 3       spam  Free entry in 2 a wkly comp to win FA Cup fina...         NaN
# 4        ham  U dun say so early hor... U c already then say...         NaN
# ...      ...                                                ...         ...
# 5568    spam  This is the 2nd time we have tried 2 contact u...         NaN
# 5569     ham              Will Ì_ b going to esplanade fr home?         NaN
# 5570     ham  Pity, * was in mood for that. So...any other s...         NaN
# 5571     ham  The guy did some bitching but I acted like i'd...         NaN
# 5572     ham                         Rofl. Its true to its name         NaN
#
# ...

# %%
columnas_eliminar = ['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12']

# %%
data = datos.drop(columnas_eliminar, axis=1)

# %%
data
# Out:
#      Column1                                            Column2
# 0         v1                                                 v2
# 1        ham  Go until jurong point, crazy.. Available only ...
# 2        ham                      Ok lar... Joking wif u oni...
# 3       spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4        ham  U dun say so early hor... U c already then say...
# ...      ...                                                ...
# 5568    spam  This is the 2nd time we have tried 2 contact u...
# 5569     ham              Will Ì_ b going to esplanade fr home?
# 5570     ham  Pity, * was in mood for that. So...any other s...
# 5571     ham  The guy did some bitching but I acted like i'd...
# 5572     ham                         Rofl. Its true to its name
#
# [5573 rows x 2 columns]

# %%
data.to_csv('nuevo_data.csv', header=['v1', 'v2'],index=False)

# %%
da = pd.read_csv("nuevo_data.csv", encoding='latin-1')
da
# Out:
#         v1                                                 v2
# 0       v1                                                 v2
# 1      ham  Go until jurong point, crazy.. Available only ...
# 2      ham                      Ok lar... Joking wif u oni...
# 3     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4      ham  U dun say so early hor... U c already then say...
# ...    ...                                                ...
# 5568  spam  This is the 2nd time we have tried 2 contact u...
# 5569   ham             Will Ã_ b going to esplanade fr home?
# 5570   ham  Pity, * was in mood for that. So...any other s...
# 5571   ham  The guy did some bitching but I acted like i'd...
# 5572   ham                         Rofl. Its true to its name
#
# [5573 rows x 2 columns]
