# %% [markdown]
# # Nombre: Josue Alejandro Sauca Pucha
# # Fecha: 12-07-2023

# %% [markdown]
# Evaluación Unidad 2
# July 12, 2023
# 1 Evaluación Unidad 2
# Parte1
# 1. Descargue el archivo Breast Cancer Wisconsin (Diagnostic) ubicado en el repositorio UCI
# 2. Lea la descripción del archivo

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Leemos el archivo descargado con extension .data
data1 =  pd.read_csv('wdbc.data',delimiter=',',header=None)
data1.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
#Asiganmos el nombre a las columnas con la documentacion de la pagina https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic
data1.columns =['id','diagnosis','radius1','texture1',
                'perimeter1','area1','smoothness1','compactness1'
                ,'concavity1','concave_points1','symmetry1'
                ,'fractal_dimension1','radius2','texture2','perimeter2',
               'area2','smoothness2','compactness2','concavity2',
                'concave_points2','symmetry2','fractal_dimension2','radius3',
               'texture3','perimeter3','area3','smoothness3','compactness3'
               ,'concavity3','concave_points3','symmetry3','fractal_dimension3']

# %% [markdown]
# 3. Divida el archivo de dos partes que ocupen el 95% para entrenamiento y el 5% para test

# %%
test_data
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 204   12.470     18.60       81.09   481.9      0.09965       0.10580
# 70    18.940     21.31      123.60  1130.0      0.09009       0.10290
# 131   15.460     19.48      101.70   748.9      0.10920       0.12230
# 431   12.400     17.68       81.47   467.8      0.10540       0.13160
# 540   11.540     14.44       74.65   402.9      0.09984       0.11200
# 567   20.600     29.33      140.10  1265.0      0.11780       0.27700
# 369   22.010     21.90      147.20  1482.0      0.10630       0.19540
# 29    17.570     15.05      115.00   955.1      0.09847       0.11570
# 81    13.340     15.86       86.49   520.0      0.10780       0.15350
# 477   13.900     16.62       88.97   599.4      0.06828       0.05319
# 457   13.210     25.25       84.10   537.9      0.08791       0.05205
# 167   16.780     18.80      109.30   886.3      0.08865       0.09182
# ...

# %%
# Con la funcion train_test_split dividimos en dos parte el datase,
#la primera parte para entrenamiento y la segunda para test, en este caso el test de 5%
#y lo demas queda para entrenamiento el 95%

X = data1.iloc[:, 2:]  # La variable X contiene los datos desde el radio hasta fractal_dimension3
y = data1.iloc[:, 1]   # Contiene todos los datos del diagnostico

train_data, test_data, train_labels, test_labels = train_test_split(X, y, test_size=0.05, random_state=42)

print("Training set:")
print(train_data.head())

print("Test set:")
print(test_data.head())
# Out:
# Training set:
#      radius1  texture1  perimeter1  area1  smoothness1  compactness1  \
# 72    17.200     24.52      114.20  929.4      0.10710       0.18300
# 551   11.130     22.44       71.49  378.4      0.09566       0.08194
# 158   12.060     12.74       76.84  448.6      0.09311       0.05241
# 424    9.742     19.12       61.93  289.7      0.10750       0.08333
# 532   13.680     16.33       87.76  575.5      0.09277       0.07255
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# 72     0.169200          0.07944     0.1927             0.06487  ...
# 551    0.048240          0.02257     0.2030             0.06552  ...
# 158    0.019720          0.01963     0.1590             0.05907  ...
# 424    0.008934          0.01967     0.2538             0.07029  ...
# 532    0.017520          0.01880     0.1631             0.06155  ...
#
#      texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# ...

# %%
X
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  \
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %% [markdown]
# 4. Utilice el archivo para aplicar los siguientes algoritmos de clasificaicón supervisada: NB, SVM,
# DT, pude utilizar weka o python.
# 5. Con el archivo de test realice la predicción de los datos con los 3 modelos

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier

"""
A continuacion se va a entrenar con Naive Bayes, para lo cual se envia los datos entrenados y la columna del diagnostico 
"""
nb = GaussianNB()
nb.fit(train_data, train_labels) #con esta funcion se ajusta el modelo a los datos de entrenamiento en base a los datos para el entrenamiento y la columna de diagnostico
nb_score = nb.score(test_data, test_labels)#con esta funcion se compara las predicciones realizadas por el modelo entrenado y calcula la precisión del modelo
print("Naive Bayes porcentaje:", nb_score)

"""
A continuacion se va a entrenar con Naive Bayes, para lo cual se envia los datos entrenados y la columna del diagnostico 
"""
svm_clf = svm.SVC(kernel='linear')
svm_clf.fit(train_data, train_labels)
svm_score = svm_clf.score(test_data, test_labels)
print("SVM porcentaje:", svm_score)

# Entrenar y probar el clasificador Decision Tree
dt = DecisionTreeClassifier()
dt.fit(train_data, train_labels)
dt_score = dt.score(test_data, test_labels)
print("Decision Tree porcentaje:", dt_score)
# Out:
# Naive Bayes porcentaje: 0.9655172413793104
# SVM porcentaje: 0.9655172413793104
# Decision Tree porcentaje: 0.896551724137931

# %% [markdown]
# 6. Agregue una columna por cada modelo denominada predicciones al archivo de test y súbalo
# al eva

# %%
test_data
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 204   12.470     18.60       81.09   481.9      0.09965       0.10580
# 70    18.940     21.31      123.60  1130.0      0.09009       0.10290
# 131   15.460     19.48      101.70   748.9      0.10920       0.12230
# 431   12.400     17.68       81.47   467.8      0.10540       0.13160
# 540   11.540     14.44       74.65   402.9      0.09984       0.11200
# 567   20.600     29.33      140.10  1265.0      0.11780       0.27700
# 369   22.010     21.90      147.20  1482.0      0.10630       0.19540
# 29    17.570     15.05      115.00   955.1      0.09847       0.11570
# 81    13.340     15.86       86.49   520.0      0.10780       0.15350
# 477   13.900     16.62       88.97   599.4      0.06828       0.05319
# 457   13.210     25.25       84.10   537.9      0.08791       0.05205
# 167   16.780     18.80      109.30   886.3      0.08865       0.09182
# ...

# %%
type(nb.predict(test_data))
# Out:
# numpy.ndarray

# %%
type(dt.predict(test_data))
# Out:
# numpy.ndarray

# %%
svm_clf.predict(test_data)
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B'], dtype=object)

# %%
test_data
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 204   12.470     18.60       81.09   481.9      0.09965       0.10580
# 70    18.940     21.31      123.60  1130.0      0.09009       0.10290
# 131   15.460     19.48      101.70   748.9      0.10920       0.12230
# 431   12.400     17.68       81.47   467.8      0.10540       0.13160
# 540   11.540     14.44       74.65   402.9      0.09984       0.11200
# 567   20.600     29.33      140.10  1265.0      0.11780       0.27700
# 369   22.010     21.90      147.20  1482.0      0.10630       0.19540
# 29    17.570     15.05      115.00   955.1      0.09847       0.11570
# 81    13.340     15.86       86.49   520.0      0.10780       0.15350
# 477   13.900     16.62       88.97   599.4      0.06828       0.05319
# 457   13.210     25.25       84.10   537.9      0.08791       0.05205
# 167   16.780     18.80      109.30   886.3      0.08865       0.09182
# ...

# %%
test_data.to_csv("test.csv", index=False)

# %%
#Leemos el archivo descargado con extension .data
datos_test =  pd.read_csv('test.csv',delimiter=',')
datos_test
# Out:
#     radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    12.470     18.60       81.09   481.9      0.09965       0.10580
# 1    18.940     21.31      123.60  1130.0      0.09009       0.10290
# 2    15.460     19.48      101.70   748.9      0.10920       0.12230
# 3    12.400     17.68       81.47   467.8      0.10540       0.13160
# 4    11.540     14.44       74.65   402.9      0.09984       0.11200
# 5    20.600     29.33      140.10  1265.0      0.11780       0.27700
# 6    22.010     21.90      147.20  1482.0      0.10630       0.19540
# 7    17.570     15.05      115.00   955.1      0.09847       0.11570
# 8    13.340     15.86       86.49   520.0      0.10780       0.15350
# 9    13.900     16.62       88.97   599.4      0.06828       0.05319
# 10   13.210     25.25       84.10   537.9      0.08791       0.05205
# 11   16.780     18.80      109.30   886.3      0.08865       0.09182
# 12   14.970     19.76       95.50   690.2      0.08421       0.05352
# ...

# %%
datos_test['SVM_Predicion'] = dt.predict(test_data)

# %%
datos_test['Naive_Bayes_Predicion'] = nb.predict(test_data)

# %%
datos_test["Decision_Tree_Predicion"] = svm_clf.predict(test_data)

# %%
datos_test.to_csv("test.csv", index=False)

# %% [markdown]
# Parte 2
# 1. Realice una análisis de correlación de las varibles del archivo completo descargado.
# 2. Utilice las 5 variables que más se correlacionan con el diagnóstico de cancer.
# 3. Con los registros de las 5 features aplique nuevamente los algoritmos NB, SVM, DT, en weka
# o python. Debe utilizar el archivo de train.
# 4. Ahora realice la predicción con los 3 modelos generados y el archivo de test.
# 5. Agregue una columna por cada modelo denominada predicciones al archivo de test y súbalo
# al eva.

# %%
#Leemos el archivo descargado con extension .data
data2 =  pd.read_csv('wdbc.data',delimiter=',',header=None)
data2.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
correlation_matrix = data2.corr()

# Imprimir la matriz de correlación
correlation_matrix
# Out:
#           0         2         3         4         5         6         7   \
# 0   1.000000  0.074626  0.099770  0.073159  0.096893 -0.012968  0.000096
# 2   0.074626  1.000000  0.323782  0.997855  0.987357  0.170581  0.506124
# 3   0.099770  0.323782  1.000000  0.329533  0.321086 -0.023389  0.236702
# 4   0.073159  0.997855  0.329533  1.000000  0.986507  0.207278  0.556936
# 5   0.096893  0.987357  0.321086  0.986507  1.000000  0.177028  0.498502
# 6  -0.012968  0.170581 -0.023389  0.207278  0.177028  1.000000  0.659123
# 7   0.000096  0.506124  0.236702  0.556936  0.498502  0.659123  1.000000
# 8   0.050080  0.676764  0.302418  0.716136  0.685983  0.521984  0.883121
# 9   0.044158  0.822529  0.293464  0.850977  0.823269  0.553695  0.831135
# 10 -0.022114  0.147741  0.071401  0.183027  0.151293  0.557775  0.602641
# 11 -0.052511 -0.311631 -0.076437 -0.261477 -0.283110  0.584792  0.565369
# 12  0.143048  0.679090  0.275869  0.691765  0.732562  0.301467  0.497473
# ...

# %%
#Asiganmos el nombre a las columnas con la documentacion de la pagina https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic
data2.columns =['id','diagnosis','radius1','texture1',
                'perimeter1','area1','smoothness1','compactness1'
                ,'concavity1','concave_points1','symmetry1'
                ,'fractal_dimension1','radius2','texture2','perimeter2',
               'area2','smoothness2','compactness2','concavity2',
                'concave_points2','symmetry2','fractal_dimension2','radius3',
               'texture3','perimeter3','area3','smoothness3','compactness3'
               ,'concavity3','concave_points3','symmetry3','fractal_dimension3']

# %%
columnas_seleccionadas = ['perimeter3','radius3','perimeter1','area1','concave_points1']
data2 = data2.loc[:, columnas_seleccionadas]

# %%
data2
# Out:
#      perimeter3  radius3  perimeter1   area1  concave_points1
# 0        184.60   25.380      122.80  1001.0          0.14710
# 1        158.80   24.990      132.90  1326.0          0.07017
# 2        152.50   23.570      130.00  1203.0          0.12790
# 3         98.87   14.910       77.58   386.1          0.10520
# 4        152.20   22.540      135.10  1297.0          0.10430
# ..          ...      ...         ...     ...              ...
# 564      166.10   25.450      142.00  1479.0          0.13890
# 565      155.00   23.690      131.20  1261.0          0.09791
# 566      126.70   18.980      108.30   858.1          0.05302
# 567      184.60   25.740      140.10  1265.0          0.15200
# 568       59.16    9.456       47.92   181.0          0.00000
#
# [569 rows x 5 columns]

# %%
X = data2.iloc[:, :]  # La variable X contiene los datos desde el radio hasta fractal_dimension3

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
X
# Out:
#      perimeter3  radius3  perimeter1   area1  concave_points1
# 0        184.60   25.380      122.80  1001.0          0.14710
# 1        158.80   24.990      132.90  1326.0          0.07017
# 2        152.50   23.570      130.00  1203.0          0.12790
# 3         98.87   14.910       77.58   386.1          0.10520
# 4        152.20   22.540      135.10  1297.0          0.10430
# ..          ...      ...         ...     ...              ...
# 564      166.10   25.450      142.00  1479.0          0.13890
# 565      155.00   23.690      131.20  1261.0          0.09791
# 566      126.70   18.980      108.30   858.1          0.05302
# 567      184.60   25.740      140.10  1265.0          0.15200
# 568       59.16    9.456       47.92   181.0          0.00000
#
# [569 rows x 5 columns]

# %%
train_data1, test_data1, train_labels1, test_labels1 = train_test_split(X, y, test_size=0.05)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier

nb = GaussianNB()
nb.fit(train_data1, train_labels1) 
nb_score = nb.score(test_data1, test_labels1)
print("Naive Bayes porcentaje:", nb_score)


svm_clf = svm.SVC(kernel='linear')
svm_clf.fit(train_data1, train_labels1)
svm_score = svm_clf.score(test_data1, test_labels1)
print("SVM porcentaje:", svm_score)

# Entrenar y probar el clasificador Decision Tree
dt = DecisionTreeClassifier()
dt.fit(train_data1, train_labels1)
dt_score = dt.score(test_data1, test_labels1)
print("Decision Tree porcentaje:", dt_score)
# Out:
# Naive Bayes porcentaje: 0.8275862068965517
# SVM porcentaje: 0.8620689655172413
# Decision Tree porcentaje: 0.896551724137931

# %%
dt.predict(test_data1)
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B'], dtype=object)

# %%
svm_clf.predict(test_data1)
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'M', 'B',
#        'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B'], dtype=object)

# %%
nb.predict(test_data1)
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B',
#        'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B'], dtype='<U1')

# %%
test_data1.to_csv("test1.csv", index=False)

# %%
datos_test1 =  pd.read_csv('test1.csv',delimiter=',')
datos_test1
# Out:
#     perimeter3  radius3  perimeter1   area1  concave_points1
# 0        67.03   10.410       60.11   269.4         0.015040
# 1        75.79   12.020       59.82   278.6         0.014060
# 2        96.05   14.970       81.09   481.9         0.038210
# 3        94.17   14.670       88.06   582.7         0.019170
# 4        76.43   11.620       70.79   365.6         0.027880
# 5        95.78   14.960       87.76   571.1         0.031600
# 6       108.60   16.990       88.05   582.7         0.044890
# 7       184.60   25.380      122.80  1001.0         0.147100
# 8        58.08    9.092       53.27   203.9         0.021680
# 9       171.10   25.300      135.90  1264.0         0.150400
# 10       91.88   14.240       83.19   506.3         0.023150
# 11      127.10   19.820      114.60   992.1         0.041780
# 12      106.00   16.010       92.33   595.9         0.067590
# 13      129.10   19.760      117.40  1024.0         0.057780
# ...

# %%
datos_test1['SVM_Predicion'] = dt.predict(test_data1)

# %%
datos_test1['Naive_Bayes_Predicion'] = nb.predict(test_data1)

# %%
datos_test1["Decision_Tree_Predicion"] = svm_clf.predict(test_data1)

# %%
datos_test1.to_csv("test1.csv", index=False)

# %% [markdown]
# Parte 3
# 1. Realice una análisis de la ejecución de los algoritmos aplicados en las dos partes anteriores
# y elija cuál de las dos partes es la mejor para aplicar en este caso. Para la explicación debe
# realizar una comparación de los algoritmos y argumentar porque elije la opción.

# %% [markdown]
# En el caso aplicado se pudo evidenciar el uso de los dos algoritmos pero yo personalmente me quedaria con el primero y es porque:
#
#     * El primero tiene mas argumentos respecto a la variables para determinar de mejor manera la deteccion de cancer.
#     * Para determinar el diagnostico si se aplica el segundo algoritmo sera mas reducido ya que tiene menos datos a tomar en cuenta a diferencia del primero que tiene mas argumento y no segmenta cierta informacion
#     * Se puede ver que la tendencia del segundo clasifica con mayor frecuencia los casos benignos a diferencia de los malignos, esto no es del todo cierto ya que el dataset original tiene mayor casos malignos que benignos y esto puede dar a malas interpretaciones
#     * El dataset del primero obtiene mejores relaciones con el dataset original a diferencia del segundo.
